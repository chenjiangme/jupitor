# %% [markdown]
# # Jupitor Analysis Notebook
# Example notebook for market data analysis.

# %%
from jupitor.data import read_daily_bars, list_symbols
from jupitor.analysis import daily_returns, sharpe_ratio

# %%
# List available symbols
# symbols = list_symbols('us')
# print(f'Available symbols: {len(symbols)}')
